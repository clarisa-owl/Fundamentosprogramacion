# %% [markdown]
# <a href="https://colab.research.google.com/github/clarisa-owl/Fundamentosprogramacion/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X = 5
X = "hola mundo"
X = True
print ( "la variable X es igual",X)
# Out:
# la variable X es igual hola mundo
