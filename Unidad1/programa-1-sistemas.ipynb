# %% [markdown]
# <a href="https://colab.research.google.com/github/clarisa-owl/Fundamentosprogramacion/blob/main/Unidad1/programa-1-sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingenieria en sistemas computacionales**
#
# ##**Fundamentos de programacion**
#
# ## **Unidad 1**
#
# ### Practica 1: Introduccion al lenguaje de programacion Phyton
#
# Docente: **Jose Gabriel Rodriguez Rivas**
#
# Alumno: **Clarisa Alvarado Ramos**

# %%
X = 5
X="hola mundo"
X= True
print("el valor de x es", "X" )
# Out:
# el valor de x es X

# %%
base = int (input ("dame la altura de la base") )
altura = int (input ("dame la altura del triangulo") )
area = (base*altura)/2
print (" el area del triangulo es", area)
# Out:
# dame la altura de la base10
# dame la altura del triangulo5
#  el area del triangulo es 25.0

# %%
variable1= 30
variable2= 50
if variable1 > variable2:
  print ("la variable 1 es mayor que la variable 2")
else: print ("la variable 2 es mayor que la variable 1")
# Out:
# la variable 2 es mayor que la variable 1

# %%
variable1= 30
variable2= 50
if variable1 > variable2:
 print(variable1, "es mayor que", variable2)
else:
 print(variable2, "es mayor que", variable1)
# Out:
# 50 es mayor que 30

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
    print ( variable1, "es mayor que", variable2)
elif variable1 == variable2:
    print( variable2, "es igual que", variable1)
else:
     print(variable2, "es mayor que", variable1)
# Out:
# 70 es igual que 70

# %%
edad = int(input("dame tu edad"))
if edad <= 10:
  print ("eres un niño")
elif edad <= 18:
    print ("eres un adolescente")
elif edad <=30:
    print ("eres un adulto joven")
elif edad <=65:
    print ("eres un adulto")
else:
    print ("eres un dullto mayor")
# Out:
# dame tu edad10
# eres un niño

# %%
edad = int(input("dame tu edad"))
if edad >= 65:
  print ("eres un adulto mayor")
elif edad >= 30:
    print ("eres un adulto joven")
elif edad >=18:
    print ("eres un adolescente")
elif edad >=10:
    print ("eres un niño")
# Out:
# dame tu edad65
# eres un adulto mayor

# %%
5 > 10 # esto es un comentario, el resultado es un valor boleano
       # que me regresa verdadero o falso dependiendo de si cumple o no
# Out:
# False

# %%
10 >5 and 10 > 7 and 10 < 1
# Out:
# True

# %%
# tenemos tres condiciones y operador and y todas deben cumplirs para que el resultado sea verdadero
10 >5 and 10 > 7 and 10 > 11
# Out:
# False

# %%
10 >5 or 10 > 7 or 10 > 11
# Out:
# True

# %%
edad = int(input("dame tu edad"))
if edad >= 66:
  print ("eres un adulto mayor")
elif edad >= 31 and edad <=65:
  print ("eres un adulto")
elif edad >= 19 and edad <= 30:
    print ("eres un adulto joven")
elif edad >=11 and edad <= 18:
    print ("eres un adolescente")
else:
    print ("eres un niño")
# primero mayor que y luego menor que
# Out:
# dame tu edad14
# eres un adolescente

# %%
## instruccion for siirve ´para repetir instrucciones
tabla = 7
for i in range(10):
  print (tabla, "*", i , "=", tabla*i )
# Out:
# 7 * 0 = 0
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63

# %%
edad = int(input("dame tu edad"))
if edad <= 10:
  print ("eres un niño")
if edad <= 18:
    print ("eres un adolescente")
if edad <=30:
    print ("eres un adulto joven")
if edad <=65:
    print ("eres un adulto")
else:
    print ("eres un dullto mayor")
# SI SE USA IF PUEDE  PASAR QUE ENTRE DENTRO DE VARIAS CONDICIONES Y TODAS SE PONGAN, por eso en estos casos usamos elif
# Out:
# dame tu edad10
# eres un niño
# eres un adolescente
# eres un adulto joven
# eres un adulto

# %%
tabla = int(input("¿que tabla de multiplicar quieres"))
inicio = int(input("¿en que tabla quieres empezar?"))
fin = int(input("¿en que tabla quieres terminar"))
salto = int(input("¿de cuanto quieres que sea el salto?"))

for tabla in range (inicio, fin, salto):
         print ("tabla del", tabla)
for numero in range (1, 11):
            print(tabla, "*", numero, "=", tabla * numero)
# Out:
# ¿que tabla de multiplicar quieres7
# ¿en que tabla quieres empezar?4
# ¿en que tabla quieres terminar7
# ¿de cuanto quieres que sea el salto?2
# tabla del 4
# tabla del 6
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60

# %%
numero = 5

while numero <= 5 and numero >= 1:
  print(numero)
  print("dentro del while")
  numero = numero - 1
print("fuera del while")
# Out:
# 5
# dentro del while
# 4
# dentro del while
# 3
# dentro del while
# 2
# dentro del while
# 1
# dentro del while
# fuera del while

# %% [markdown]
# ### **listas en phyton**

# %%
alumnos = ["Ana", "Juan", "Carlos"]
print ( alumnos)
print (alumnos[0])
print (alumnos[2])
# Out:
# ['Ana', 'Juan', 'Carlos']
# Ana
# Carlos

# %%
#podemos modificar el numero de la lista insertando nombre y cambiando el numero y pocision por el nuevo valor
print (alumnos)
alumnos[2]="Carlos"
# Out:
# ['Ana', 'Juan', 'Carlos']

# %%
print (alumnos)
print (alumnos [-0])
print(alumnos [-2])
# Out:
# ['Ana', 'Juan', 'Carlos']
# Ana
# Juan

# %%
print (alumnos)
alumnos.append ("Sandra")
print (alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos']
# ['Ana', 'Juan', 'Carlos', 'Sandra']

# %%
print(alumnos)
alumnos.insert (2,"sofia")
print (alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos', 'Sandra']
# ['Ana', 'Juan', 'sofia', 'Carlos', 'Sandra']

# %%
# remove mueve un elemento de la lista con el primer valor que encuentra
print (alumnos)
alumnos.remove("sofia")
print (alumnos)
# Out:
# ['Ana', 'Juan', 'sofia', 'Carlos', 'Sandra']
# ['Ana', 'Juan', 'Carlos', 'Sandra']

# %%
# marca error porque queremos añadir un indice que no existe
print (alumnos[2])
print (alumnos [7])
# Out:
# Sandra
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_397/147917297.py in <cell line: 0>()
#       1 # marca error porque queremos añadir un indice que no existe
#       2 print (alumnos[2])
# ----> 3 print (alumnos [7])
#
# IndexError: list index out of range

# %%
#permite eliminar un elemento de la lista especificando su pocision
print (alumnos)
alumnos.pop (1)
print (alumnos)
# Out:
# ['Ana', 'Juan', 'Carlos', 'Sandra']
# ['Ana', 'Carlos', 'Sandra']

# %%
print (alumnos)
print (alumnos)
# Out:
# ['Ana', 'Carlos', 'Sandra']
# ['Ana', 'Carlos', 'Sandra']

# %%
print("numero de elementos de la lista", len(alumnos))
#len permite conocer el numero de elemeentos de la lista
# Out:
# numero de elementos de la lista 3

# %%
print (alumnos)
for x in alumnos:
   print (x)
if x == "manuel":
   print ("encontramos a manuel")
#break forza a salir del ciclo
# Out:
# ['Ana', 'Carlos', 'Sandra']
# Ana
# Carlos
# Sandra
