# %% [markdown]
# <a href="https://colab.research.google.com/github/clarisa-owl/Fundamentosprogramacion/blob/main/Unidad1/Sistemas%20De%20Prestamos%20Versi%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ingenieria en sistemas computacionales**
#
# ##**Fundamentos de programacion**
#
# ## **Unidad 1**
#
# ### Sistema de gestion de prestamos y reservacion de computadoras - version 1
#
# Docente: **Jose Gabriel Rodriguez Rivas**
#
# Alumno: **Clarisa Alvarado Ramos**

# %%
 #=============================
#SISTEMA DE PRESTAMOS
#version 1 - programacion basica y uso de listas
#=============================

#lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201", "26040202", "26040203"]

#cada valor en la lista de computadoras tienen su lista correspondiente en el
#aula donde esta ubicada el software instalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03"
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03"
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]

aulas = [ "LC1", "LC1", "LC1"
          "LC2", "LC2", "LC2"
          "LC3", "LC3", "LC3", "LC3"]

software = ["Phyton, VS code", "Phyton, Java, VS code", "autoCAD, MATLAB"
            "Phyton, VS code", "Phyton, Java, VS code", "autoCAD, MATLAB"
            "Phyton, VS code", "Phyton, Java, VS code", "autoCAD, MATLAB", "Phyton, VS code"]

estados = ["Disponible", "Prestada", "Reservada"
           "Disponible", "Prestada", "Reservada"
           "Disponible", "Prestada", "Reservada", "Mantenimiento"]

#MENU PRINCIPAL
#Usamos un ciclo while que se repetira indefinidamente hasta que el usuario
#Tecle la opcion 7 (salir) o cualquier nmero superior a 7

opcion = 0
while opcion <= 6:
  print("\n====================================")
  print("SISTEMA DE PRESTAMOS")
  print("=====================================")
  print("1. Consultar computadoras")
  print("2. Buscar por software")
  print("3. Solicitar prestamo")
  print("4. Devolver computadora")
  print("5. Crear reservacion")
  print("6. Agregar computadora")
  print("7. salir")
  print("=====================================")
  opcion = int(input("Seleccione una opcion: "))

  #1. Consultar computadoras
  #Si el usuario usa la opcion 1 se hace un ciclo for que recorre
  #Toda la lista que computadoras e imprime los valoresde la demas listas
if opcion == 1:
  print =("\n---COMPUTADORAS---")
  for i in range(len(computadoras)):
    print =("Aula:", aulas [i], "ID:", computadoras [i], "software:", software [i], "Estado:", estados, [i], "-----------")

#2. Buscar por software
elif opcion == 2:
    programa = input("\ngrese el software que desea buscar: ")
    print("\n---RESULTADOS---")
    encontrado = False
 for i in range(len(computadoras)):
#la funcion (lower) convierte a minusculas el texto de esta forma
#nos aseguramos que el texto a buscar y la informacion de las listas
#este en minusculas y no tengamos problemas de que no encuentra algun programa
#porque este escrito de forma diferente usando mayusculas y minusculas

  if programa.lower() in software [i].lower():
   print ("ID:", computadoras [i])
   print ("Aula:", aula [i])
   print ("Software:", software [i])
   print ("Estado:", estados [i])
encontrado = True

if encontrado == False:
  print("No se encontraron computadoras con ese software.")

#3. Solicitar el prestamo
elif opcion == 3:
    print("\n---SOLICITAR PRESTAMO---")
    num_control = input("\nIngrese el numero de control: ")
    encontrado1 = False
#Verificar si el alumno esta en la lista o BD
if num_control in alumnos:
#Si existe, continuamos con el procedimiento
    encontrado1 = True
    id_computadora = input("ingrese el ID de la computadora: ")
    encontrado2 = False
    for i in range(len(computadoras)):
      if computadoras [i] == id_computadoras:
        encontrado2 = True
        if estados[i] =="Disponible":
           estados[i] = "Prestada"
           print("Prestamo regitrado correctamente.")
           print("Computadora:", computdoras[i])
           print("Aulas:", aulas[i])
        else:
           print("La computadora no esta disponible")
      if encontrado2 == False:
           print("La computadora no existe")
      if encontrado1 == False:
           print("El alumno no existe.")
elif opcion== 3:
  print("---SOLICITAR PRESTAMO---")
  num_control == input("numero de control del alumno")
  if num_control in alumnos:
    programa= input("que programa necesita")
    for i in range(len(computadoras)):
      if programa.lower() in software[i].lower():
        if estados[i]=="Disponible":
           estados[i]="Prestada"
        print("Se asigno a computadora", computadoras[i],
               "que esta el aula", aulas[i])
        break
  else:
       print("Si se encontr el software pero esta", estados[i])
else:
  print("el alumno no existe en esta lista")

elif opcion == 4
print("\n---DEVOLVER COMPUTADORA---")
id_pc = input("Dame el id de la computadora: ")
existe =False
for i in range(len(computadoras)):
  if computadoras[i] == id_pc:
    id estados[i] = "prestada" or estados[i]=="reservada"
      estados[i] = "disponible"
      print("la computadora", id_pc, "ya esta disponible")
      break
  else:
    print("la computadora", id_pc, "no esta prestada/reservada")

#6. Agregar computadora
elif opcion == 6:
 print("\n---AGREGAR COMPUTADORA---")
  Id_computadoras =input("ID de la computadora")
  aula = input("Aula: ")
  Programas = input("software inatalado: ")
  computadoras.append(id_computadoras)
  aulas.append(aula)
  software.append(programas)
  estados.append("disponible")
  print("\n computadora agregada correctamente.")
# Out:
#   File "/tmp/ipykernel_535/3870857259.py", line 117
#     elif opcion == 4
#     ^
# SyntaxError: invalid syntax
